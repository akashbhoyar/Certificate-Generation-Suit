# %%
import mysql.connector
db=mysql.connector.connect(host='localhost',user='root',passwd='********',database="project")
cursor=db.cursor()
sql="create table prot2(roll_no VARCHAR(250),name VARCHAR(250),father VARCHAR(250),mother VARCHAR(250),caste VARCHAR(250),place_birth VARCHAR(250),DOB VARCHAR(250),DOB2 VARCHAR(250),last_sch_clg VARCHAR(250),DOA VARCHAR(250),mob VARCHAR(250),progress VARCHAR(250),conduct VARCHAR(250),date_leaving VARCHAR(250),year_studying VARCHAR(250),reason_leaving VARCHAR(250),remark VARCHAR(250))"
cursor.execute(sql)
db.close()
